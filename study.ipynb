# %%
import numpy as np

# %%
path = 'data/data_3d_' + 'h36m' + '.npz'
print(dataset_path)
# Out:
# data/data_3d_h36m.npz

# %%
data = np.load(path, allow_pickle=True)['positions_3d'].item()
for i in data:
    print()
    for j in data[i]:
        print(j)
        #print(data[i][j].shape)
# Out:
# Directions 1
# Photo 1
# SittingDown 2
# Eating
# WalkDog 1
# WalkDog
# Purchases
# Posing
# Directions
# Walking
# Greeting
# Phoning 1
# Posing 1
# Sitting 2
# Waiting 1
# Photo
# Purchases 1
# Greeting 1
# Sitting 1
# Smoking 1
# WalkTogether
# Waiting
# WalkTogether 1
# SittingDown
# Phoning
# Eating 2
# Walking 1
# Smoking
# Discussion
# Discussion 1
#
# Directions 1
# Discussion 2
# Eating
# WalkDog 1
# Discussion 3
# Eating 1
# WalkDog
# Purchases
# Posing
# Walking
# Phoning 1
# Posing 1
# Greeting 2
# Waiting 1
# Photo
# Purchases 1
# Greeting 1
# Sitting 1
# Smoking 1
# Waiting 2
# WalkTogether
# Sitting
# WalkTogether 1
# SittingDown
# Phoning
# Directions 2
# Photo 2
# SittingDown 1
# Walking 1
# Smoking
#
# Directions 1
# Photo 1
# WalkDog 1
# Eating 1
# WalkDog
# Purchases
# Posing
# Directions
# Walking
# Greeting
# Phoning 1
# Sitting 2
# Photo
# Purchases 1
# Posing 2
# Greeting 1
# Sitting 1
# Smoking 1
# WalkTogether
# Waiting 3
# Waiting
# WalkTogether 1
# SittingDown
# Phoning
# Eating 2
# SittingDown 1
# Walking 1
# Smoking
# Discussion
# Discussion 1
#
# Directions 1
# Photo 1
# Walking 2
# Eating
# WalkDog 1
# Eating 1
# WalkDog
# Purchases
# Posing
# Directions
# Greeting
# Posing 1
# Waiting 1
# Photo
# Purchases 1
# Phoning 2
# Greeting 1
# Sitting 1
# Smoking 1
# Waiting 2
# WalkTogether
# Sitting
# WalkTogether 1
# SittingDown
# Phoning
# SittingDown 1
# Walking 1
# Smoking
# Discussion
# Discussion 1
#
# Directions 1
# Photo 1
# Eating
# WalkDog 1
# Eating 1
# WalkDog
# WalkTogether 2
# Purchases
# Posing
# Directions
# Walking
# Greeting
# Phoning 1
# Posing 1
# Waiting 1
# Photo
# Purchases 1
# Greeting 1
# Sitting 1
# Smoking 1
# Sitting
# Waiting
# WalkTogether 1
# SittingDown
# Phoning
# SittingDown 1
# Walking 1
# Smoking
# Discussion
# Discussion 1
#
# Directions 1
# Photo 1
# Discussion 2
# Eating
# WalkDog 1
# Eating 1
# WalkDog
# Purchases
# Posing
# Directions
# Walking
# Greeting
# Phoning 1
# Posing 1
# Waiting 1
# Photo
# Purchases 1
# Greeting 1
# Sitting 1
# Smoking 1
# WalkTogether
# Sitting
# Waiting
# WalkTogether 1
# SittingDown
# Phoning
# SittingDown 1
# Walking 1
# Smoking
# Discussion 1
#
# Directions 1
# Photo 1
# Discussion 2
# Eating
# WalkDog 1
# Eating 1
# WalkDog
# Purchases
# Posing
# Walking
# Greeting
# Posing 1
# Greeting 2
# Waiting 1
# Smoking 2
# Photo
# Purchases 1
# Phoning 2
# Sitting 1
# WalkTogether
# Sitting
# Waiting
# WalkTogether 1
# SittingDown
# Phoning 3
# SittingDown 1
# Walking 1
# Smoking
# Discussion 1

# %%
import numpy as np
class Skeleton:
    def __init__(self, parents, joints_left, joints_right):
        assert len(joints_left) == len(joints_right)
        
        self._parents = np.array(parents)
        self._joints_left = joints_left
        self._joints_right = joints_right
        self._compute_metadata()
    
    def num_joints(self):
        return len(self._parents)
    
    def parents(self):
        return self._parents
    
    def has_children(self):
        return self._has_children
    
    def children(self):
        return self._children
    
    def remove_joints(self, joints_to_remove):
        """
        Remove the joints specified in 'joints_to_remove'.
        """
        valid_joints = []
        for joint in range(len(self._parents)):
            if joint not in joints_to_remove:
                valid_joints.append(joint)

        for i in range(len(self._parents)):
            while self._parents[i] in joints_to_remove:
                self._parents[i] = self._parents[self._parents[i]]
                
        index_offsets = np.zeros(len(self._parents), dtype=int)
        new_parents = []
        for i, parent in enumerate(self._parents):
            if i not in joints_to_remove:
                new_parents.append(parent - index_offsets[parent])
            else:
                index_offsets[i:] += 1
        self._parents = np.array(new_parents)
        
        
        if self._joints_left is not None:
            new_joints_left = []
            for joint in self._joints_left:
                if joint in valid_joints:
                    new_joints_left.append(joint - index_offsets[joint])
            self._joints_left = new_joints_left
        if self._joints_right is not None:
            new_joints_right = []
            for joint in self._joints_right:
                if joint in valid_joints:
                    new_joints_right.append(joint - index_offsets[joint])
            self._joints_right = new_joints_right

        self._compute_metadata()
        
        return valid_joints
    
    def joints_left(self):
        return self._joints_left
    
    def joints_right(self):
        return self._joints_right
        
    def _compute_metadata(self):
        self._has_children = np.zeros(len(self._parents)).astype(bool)
        for i, parent in enumerate(self._parents):
            if parent != -1:
                self._has_children[parent] = True

        self._children = []
        for i, parent in enumerate(self._parents):
            self._children.append([])
        for i, parent in enumerate(self._parents):
            if parent != -1:
                self._children[parent].append(i)

# %%
test = Skeleton((1,2,3),[1,2,3],[4,5,6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 test = Skeleton((1,2,3),[1,2,3],[4,5,6])
#
# Input In [38], in Skeleton.__init__(self, parents, joints_left, joints_right)
#       7 self._joints_left = joints_left
#       8 self._joints_right = joints_right
# ----> 9 self._compute_metadata()
#
# Input In [38], in Skeleton._compute_metadata(self)
#      71 for i, parent in enumerate(self._parents):
#      72     if parent != -1:
# ---> 73         self._has_children[parent] = True
#      75 self._children = []
#      76 for i, parent in enumerate(self._parents):
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
test.children
# Out:
# <function __main__.Skeleton.children(self)>
